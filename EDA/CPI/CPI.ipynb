# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../data/CPI/consumer_price_index.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Columns: 1719 entries, FREQ to 2024-10
# dtypes: float64(1712), int64(1), object(6)
# memory usage: 3.3+ MB

# %%
df.head()
# Out:
#   FREQ Frequency REF_AREA Reference area  UNIT_MEASURE  \
# 0    A    Annual       ES          Spain           771
# 1    M   Monthly       PL         Poland           628
# 2    M   Monthly       AT        Austria           628
# 3    A    Annual       NO         Norway           771
# 4    M   Monthly       BE        Belgium           771
#
#                      Unit of measure  TIME_FORMAT  Time Format  BREAKS  \
# 0  Year-on-year changes, in per cent          NaN          NaN     NaN
# 1                  Index, 2010 = 100          NaN          NaN     NaN
# 2                  Index, 2010 = 100          NaN          NaN     NaN
# 3  Year-on-year changes, in per cent          NaN          NaN     NaN
# 4  Year-on-year changes, in per cent          NaN          NaN     NaN
#
#    COVERAGE  DECIMALS  Decimals  TITLE_TS    Series  1661  1662  1663  1664  \
# 0       NaN       NaN       NaN       NaN  A:ES:771   NaN   NaN   NaN   NaN
# ...

# %%
df.T.()
# Out:
#                    0        1        2       3        4         5       6    \
# FREQ                 A        M        M       A        M         M       A
# Frequency       Annual  Monthly  Monthly  Annual  Monthly   Monthly  Annual
# REF_AREA            ES       PL       AT      NO       BE        SK      RU
# Reference area   Spain   Poland  Austria  Norway  Belgium  Slovakia  Russia
# UNIT_MEASURE       771      628      628     771      771       771     628
#
#                     7        8        9       10      11            12   \
# FREQ                  M        M        M       A       A             M
# Frequency       Monthly  Monthly  Monthly  Annual  Annual       Monthly
# REF_AREA             HR       JP       DK      CN      IL            ZA
# Reference area  Croatia    Japan  Denmark   China  Israel  South Africa
# UNIT_MEASURE        771      628      771     628     771           771
#
# ...

# %%
df.T.duplicated("Reference area")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_18040/3438000252.py in ?()
# ----> 1 df.T.duplicated("Reference area")
#
# ~/lab/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, subset, keep)
#    6650         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6651         # key that doesn't exist.
#    6652         diff = set(subset) - set(self.columns)
#    6653         if diff:
# -> 6654             raise KeyError(Index(diff))
#    6655
#    6656         if len(subset) == 1 and self.columns.is_unique:
#    6657             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['Reference area'], dtype='object')
